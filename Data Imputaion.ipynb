# %% [markdown]
# # Deep Learning

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Import Libraries

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.linear_model import LinearRegression

# %% [markdown]
# ### Load Data

# %%
import pandas as pd

# %%
ls
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is 4821-D018
#
#  Directory of C:\Users\emura\Documents\ABD_YZ_Kursu\Day-9 Deep Learning
#
# 10.03.2024  01:28    <DIR>          .
# 09.03.2024  23:47    <DIR>          ..
# 09.03.2024  23:48    <DIR>          .ipynb_checkpoints
# 10.03.2024  00:15            10.480 bilgi.docx
# 10.03.2024  01:28         3.878.771 Deep Learning.ipynb
# 10.03.2024  00:16        22.866.233 deeplearning-?????.pdf
# 10.03.2024  00:17               242 ExampleData.csv
# 10.03.2024  00:17         3.448.050 kc_house.pkl
# 10.03.2024  00:17            23.873 pima-indians-diabetes.csv
#                6 File(s)     30.227.649 bytes
#                3 Dir(s)  49.292.644.352 bytes free

# %%
df=pd.read_csv('ExampleData.csv')

# %%
df.head
# Out:
# <bound method NDFrame.head of     Height   YOE  Salary
# 0    175.0   3.0     6.0
# 1    168.0   4.0     9.0
# 2    160.0  10.0    18.0
# 3      NaN  15.0    25.0
# 4    161.0   NaN    50.0
# 5    162.0   5.0    10.0
# 6    180.0   6.0    11.0
# 7      NaN   7.0     NaN
# 8    172.0   8.0    12.0
# 9    170.0   9.0    14.0
# 10   175.0   3.0     6.0
# 11   168.0   4.0     9.0
# 12   160.0  10.0    18.0
# 13     NaN  15.0    25.0
# 14   161.0   NaN    50.0
# 15   162.0   5.0    10.0
# 16   180.0   6.0    11.0
# 17     NaN   7.0     NaN
# 18   172.0   8.0    12.0
# 19   170.0   9.0    14.0
# 20   161.0   NaN    50.0
# 21   162.0   5.0    10.0
# 22   180.0   6.0    11.0
# 23     NaN   7.0     NaN
# 24   175.0   3.0     6.0>

# %% [markdown]
# ### Data Preprocessing

# %%
lr=LinearRegression()
imp=IterativeImputer(estimator=lr)
imputed_data=imp.fit_transform(df)

# %%
imputed_data
# Out:
# array([[175.        ,   3.        ,   6.        ],
#        [168.        ,   4.        ,   9.        ],
#        [160.        ,  10.        ,  18.        ],
#        [165.2752217 ,  15.        ,  25.        ],
#        [161.        ,  31.7063758 ,  50.        ],
#        [162.        ,   5.        ,  10.        ],
#        [180.        ,   6.        ,  11.        ],
#        [169.72068911,   7.        ,  12.40190985],
#        [172.        ,   8.        ,  12.        ],
#        [170.        ,   9.        ,  14.        ],
#        [175.        ,   3.        ,   6.        ],
#        [168.        ,   4.        ,   9.        ],
#        [160.        ,  10.        ,  18.        ],
#        [165.2752217 ,  15.        ,  25.        ],
#        [161.        ,  31.7063758 ,  50.        ],
#        [162.        ,   5.        ,  10.        ],
#        [180.        ,   6.        ,  11.        ],
#        [169.72068911,   7.        ,  12.40190985],
#        [172.        ,   8.        ,  12.        ],
#        [170.        ,   9.        ,  14.        ],
#        [161.        ,  31.7063758 ,  50.        ],
#        [162.        ,   5.        ,  10.        ],
#        [180.        ,   6.        ,  11.        ],
#        [169.72068911,   7.        ,  12.40190985],
#        [175.        ,   3.        ,   6.        ]])

# %%
pd.DataFrame(imputed_data)
# Out:
#              0          1         2
# 0   175.000000   3.000000   6.00000
# 1   168.000000   4.000000   9.00000
# 2   160.000000  10.000000  18.00000
# 3   165.275222  15.000000  25.00000
# 4   161.000000  31.706376  50.00000
# 5   162.000000   5.000000  10.00000
# 6   180.000000   6.000000  11.00000
# 7   169.720689   7.000000  12.40191
# 8   172.000000   8.000000  12.00000
# 9   170.000000   9.000000  14.00000
# 10  175.000000   3.000000   6.00000
# 11  168.000000   4.000000   9.00000
# 12  160.000000  10.000000  18.00000
# 13  165.275222  15.000000  25.00000
# 14  161.000000  31.706376  50.00000
# 15  162.000000   5.000000  10.00000
# 16  180.000000   6.000000  11.00000
# 17  169.720689   7.000000  12.40191
# 18  172.000000   8.000000  12.00000
# 19  170.000000   9.000000  14.00000
# 20  161.000000  31.706376  50.00000
# 21  162.000000   5.000000  10.00000
# 22  180.000000   6.000000  11.00000
# 23  169.720689   7.000000  12.40191
# 24  175.000000   3.000000   6.00000

# %%
from sklearn.impute import KNNImputer

# %%
knn=KNNImputer()

# %%
imputed_data2=knn.fit_transform(df)

# %%
pd.DataFrame(imputed_data2,columns=[df.columns])
# Out:
#    Height   YOE Salary
# 0   175.0   3.0    6.0
# 1   168.0   4.0    9.0
# 2   160.0  10.0   18.0
# 3   166.4  15.0   25.0
# 4   161.0  11.8   50.0
# 5   162.0   5.0   10.0
# 6   180.0   6.0   11.0
# 7   176.8   7.0   11.4
# 8   172.0   8.0   12.0
# 9   170.0   9.0   14.0
# 10  175.0   3.0    6.0
# 11  168.0   4.0    9.0
# 12  160.0  10.0   18.0
# 13  166.4  15.0   25.0
# 14  161.0  11.8   50.0
# 15  162.0   5.0   10.0
# 16  180.0   6.0   11.0
# 17  176.8   7.0   11.4
# 18  172.0   8.0   12.0
# 19  170.0   9.0   14.0
# 20  161.0  11.8   50.0
# 21  162.0   5.0   10.0
# 22  180.0   6.0   11.0
# 23  176.8   7.0   11.4
# 24  175.0   3.0    6.0

# %%
from sklearn.impute import SimpleImputer

# %%
imp=SimpleImputer(strategy='mean') #median mode

# %%
imputed_data3=imp.fit_transform(df)

# %%
pd.DataFrame(imputed_data3,columns=[df.columns])
# Out:
#    Height        YOE     Salary
# 0   175.0   3.000000   6.000000
# 1   168.0   4.000000   9.000000
# 2   160.0  10.000000  18.000000
# 3   168.7  15.000000  25.000000
# 4   161.0   7.045455  50.000000
# 5   162.0   5.000000  10.000000
# 6   180.0   6.000000  11.000000
# 7   168.7   7.000000  17.590909
# 8   172.0   8.000000  12.000000
# 9   170.0   9.000000  14.000000
# 10  175.0   3.000000   6.000000
# 11  168.0   4.000000   9.000000
# 12  160.0  10.000000  18.000000
# 13  168.7  15.000000  25.000000
# 14  161.0   7.045455  50.000000
# 15  162.0   5.000000  10.000000
# 16  180.0   6.000000  11.000000
# 17  168.7   7.000000  17.590909
# 18  172.0   8.000000  12.000000
# 19  170.0   9.000000  14.000000
# 20  161.0   7.045455  50.000000
# 21  162.0   5.000000  10.000000
# 22  180.0   6.000000  11.000000
# 23  168.7   7.000000  17.590909
# 24  175.0   3.000000   6.000000

# %%
pip install miceforest
# Out:
# Collecting miceforestNote: you may need to restart the kernel to use updated packages.
#
#   Downloading miceforest-5.7.0-py3-none-any.whl.metadata (43 kB)
#      ---------------------------------------- 0.0/43.9 kB ? eta -:--:--
#      --------- ------------------------------ 10.2/43.9 kB ? eta -:--:--
#      ----------------- -------------------- 20.5/43.9 kB 165.2 kB/s eta 0:00:01
#      ----------------- -------------------- 20.5/43.9 kB 165.2 kB/s eta 0:00:01
#      ----------------------------------- -- 41.0/43.9 kB 196.9 kB/s eta 0:00:01
#      -------------------------------------- 43.9/43.9 kB 197.1 kB/s eta 0:00:00
# Requirement already satisfied: lightgbm>=3.3.1 in c:\users\emura\appdata\roaming\python\python311\site-packages (from miceforest) (4.3.0)
# Requirement already satisfied: numpy in c:\programdata\anaconda3\lib\site-packages (from miceforest) (1.24.3)
# Collecting blosc (from miceforest)
#   Downloading blosc-1.11.1-cp311-cp311-win_amd64.whl.metadata (16 kB)
# Requirement already satisfied: dill in c:\programdata\anaconda3\lib\site-packages (from miceforest) (0.3.6)
# Requirement already satisfied: scipy in c:\programdata\anaconda3\lib\site-packages (from lightgbm>=3.3.1->miceforest) (1.11.1)
# Downloading miceforest-5.7.0-py3-none-any.whl (58 kB)
#    ---------------------------------------- 0.0/58.2 kB ? eta -:--:--
#    ---------------------------- ----------- 41.0/58.2 kB 653.6 kB/s eta 0:00:01
#    ---------------------------------------- 58.2/58.2 kB 509.9 kB/s eta 0:00:00
# Downloading blosc-1.11.1-cp311-cp311-win_amd64.whl (1.7 MB)
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#     --------------------------------------- 0.0/1.7 MB 2.0 MB/s eta 0:00:01
#    - -------------------------------------- 0.1/1.7 MB 787.7 kB/s eta 0:00:03
#    ---- ----------------------------------- 0.2/1.7 MB 1.3 MB/s eta 0:00:02
#    ------ --------------------------------- 0.3/1.7 MB 1.4 MB/s eta 0:00:01
#    ---------- ----------------------------- 0.4/1.7 MB 2.1 MB/s eta 0:00:01
#    ------------ --------------------------- 0.5/1.7 MB 2.0 MB/s eta 0:00:01
#    ---------------- ----------------------- 0.7/1.7 MB 2.3 MB/s eta 0:00:01
#    ---------------- ----------------------- 0.7/1.7 MB 2.3 MB/s eta 0:00:01
#    ---------------- ----------------------- 0.7/1.7 MB 2.3 MB/s eta 0:00:01
#    ------------------------ --------------- 1.0/1.7 MB 2.3 MB/s eta 0:00:01
#    ----------------------------- ---------- 1.2/1.7 MB 2.6 MB/s eta 0:00:01
#    ---------------------------------- ----- 1.4/1.7 MB 2.6 MB/s eta 0:00:01
#    ------------------------------------ --- 1.5/1.7 MB 2.6 MB/s eta 0:00:01
#    ------------------------------------ --- 1.5/1.7 MB 2.6 MB/s eta 0:00:01
#    ---------------------------------------  1.6/1.7 MB 2.4 MB/s eta 0:00:01
#    ---------------------------------------- 1.7/1.7 MB 2.2 MB/s eta 0:00:00
# Installing collected packages: blosc, miceforest
# Successfully installed blosc-1.11.1 miceforest-5.7.0

# %%
import miceforest as mf #smart impute

# %%
imp=mf.ImputationKernel(df)

# %%
imp.complete_data()
# Out:
#     Height   YOE  Salary
# 0    175.0   3.0     6.0
# 1    168.0   4.0     9.0
# 2    160.0  10.0    18.0
# 3    172.0  15.0    25.0
# 4    161.0   3.0    50.0
# 5    162.0   5.0    10.0
# 6    180.0   6.0    11.0
# 7    162.0   7.0    12.0
# 8    172.0   8.0    12.0
# 9    170.0   9.0    14.0
# 10   175.0   3.0     6.0
# 11   168.0   4.0     9.0
# 12   160.0  10.0    18.0
# 13   175.0  15.0    25.0
# 14   161.0   5.0    50.0
# 15   162.0   5.0    10.0
# 16   180.0   6.0    11.0
# 17   175.0   7.0    10.0
# 18   172.0   8.0    12.0
# 19   170.0   9.0    14.0
# 20   161.0   3.0    50.0
# 21   162.0   5.0    10.0
# 22   180.0   6.0    11.0
# 23   172.0   7.0    11.0
# 24   175.0   3.0     6.0

# %%
df2=df.ffill(axis=1) # satırı önceki değerlerle dolduruyor

# %%
df2
# Out:
#     Height    YOE  Salary
# 0    175.0    3.0     6.0
# 1    168.0    4.0     9.0
# 2    160.0   10.0    18.0
# 3      NaN   15.0    25.0
# 4    161.0  161.0    50.0
# 5    162.0    5.0    10.0
# 6    180.0    6.0    11.0
# 7      NaN    7.0     7.0
# 8    172.0    8.0    12.0
# 9    170.0    9.0    14.0
# 10   175.0    3.0     6.0
# 11   168.0    4.0     9.0
# 12   160.0   10.0    18.0
# 13     NaN   15.0    25.0
# 14   161.0  161.0    50.0
# 15   162.0    5.0    10.0
# 16   180.0    6.0    11.0
# 17     NaN    7.0     7.0
# 18   172.0    8.0    12.0
# 19   170.0    9.0    14.0
# 20   161.0  161.0    50.0
# 21   162.0    5.0    10.0
# 22   180.0    6.0    11.0
# 23     NaN    7.0     7.0
# 24   175.0    3.0     6.0

# %%
df3=df.bfill(axis=1) #satırı sonraki değerlerle dolduruyor

# %%
df3
# Out:
#     Height   YOE  Salary
# 0    175.0   3.0     6.0
# 1    168.0   4.0     9.0
# 2    160.0  10.0    18.0
# 3     15.0  15.0    25.0
# 4    161.0  50.0    50.0
# 5    162.0   5.0    10.0
# 6    180.0   6.0    11.0
# 7      7.0   7.0     NaN
# 8    172.0   8.0    12.0
# 9    170.0   9.0    14.0
# 10   175.0   3.0     6.0
# 11   168.0   4.0     9.0
# 12   160.0  10.0    18.0
# 13    15.0  15.0    25.0
# 14   161.0  50.0    50.0
# 15   162.0   5.0    10.0
# 16   180.0   6.0    11.0
# 17     7.0   7.0     NaN
# 18   172.0   8.0    12.0
# 19   170.0   9.0    14.0
# 20   161.0  50.0    50.0
# 21   162.0   5.0    10.0
# 22   180.0   6.0    11.0
# 23     7.0   7.0     NaN
# 24   175.0   3.0     6.0
